# %% [markdown]
# Import necessary files

# %%
import appeals as ap
from appeals import *
from importlib import reload
reload(ap)
# Out:
# 1.0.1
# <module 'appeals' from 'D:\\Career-Knowledge\\Portfolio\\Appeals Filed in 2017\\appeals.py'>

# %%
df = generate()
df
# Out:
#          Appeal Type            Appeal Subtype  \
# 0     Waiting for DQ                No Subtype
# 1         Section 50                 Character
# 2         Section 50                     Score
# 3         Section 50                Timeliness
# 4         Section 50                 Character
# ...              ...                       ...
# 1260      Section 50                     Psych
# 1261      Section 50                   Medical
# 1262      Section 50                Timeliness
# 1263      Section 50  Education and Experience
# 1264      Section 50  Education and Experience
#
#                                                  Agency  Status Date Filed  \
# 0                              Police Department - NYPD    Open 2017-12-29
# 1                              Police Department - NYPD    Open 2017-12-29
# 2     Department of Citywide Administrative Services...    Open 2017-12-28
# 3     Department of Citywide Administrative Services...    Open 2017-12-28
# ...

# %%
print(df.isna().sum())
print('-----------------')
display(df['Status'].value_counts())
# Out:
# Appeal Type       0
# Appeal Subtype    0
# Agency            0
# Status            0
# Date Filed        0
# Date Closed       0
# Exam No.          0
# Title             0
# Expiration        0
# Acronym           0
# dtype: int64
# -----------------
# Closed    795
# Open      470
# Name: Status, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1265 entries, 0 to 1264
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Appeal Type     1265 non-null   object
#  1   Appeal Subtype  1265 non-null   object
#  2   Agency          1265 non-null   object
#  3   Status          1265 non-null   object
#  4   Date Filed      1265 non-null   datetime64[ns]
#  5   Date Closed     1265 non-null   datetime64[ns]
#  6   Exam No.        1265 non-null   int64
#  7   Title           1265 non-null   object
#  8   Expiration      1265 non-null   datetime64[ns]
#  9   Acronym         1265 non-null   object
# dtypes: datetime64[ns](3), int64(1), object(6)
# memory usage: 99.0+ KB

# %%
agency, agx = plt.subplots(figsize=(18, 12))
sns.countplot(data=df, y='Agency', ax=agx)
agx.set_title('Appeals by Agency - 2017')
# Out:
# Text(0.5, 1.0, 'Appeals by Agency - 2017')

# %%
appsubtype, apx = plt.subplots(figsize=(18, 12))
sns.countplot(data=df, y='Appeal Subtype', ax=apx)
apx.set_title('Appeals by Subtype - 2017')
# Out:
# Text(0.5, 1.0, 'Appeals by Subtype - 2017')

# %%
apptype, atx = plt.subplots(figsize=(18, 12))
sns.countplot(data=df, y='Appeal Type', ax=atx)
atx.set_title('Appeals by Type - 2017')
# Out:
# Text(0.5, 1.0, 'Appeals by Type - 2017')

# %%
top5_agency = top_n(n=3, column='Agency')
top5_agency
# Out:
#          Appeal Type            Appeal Subtype  \
# 0     Waiting for DQ                No Subtype
# 1         Section 50                 Character
# 2         Section 50                     Score
# 3         Section 50                Timeliness
# 4         Section 50                 Character
# ...              ...                       ...
# 1256      Section 50  Education and Experience
# 1260      Section 50                     Psych
# 1262      Section 50                Timeliness
# 1263      Section 50  Education and Experience
# 1264      Section 50  Education and Experience
#
#                                                  Agency  Status Date Filed  \
# 0                              Police Department - NYPD    Open 2017-12-29
# 1                              Police Department - NYPD    Open 2017-12-29
# 2     Department of Citywide Administrative Services...    Open 2017-12-28
# 3     Department of Citywide Administrative Services...    Open 2017-12-28
# ...

# %%
topapp, tax = plt.subplots(figsize=(18, 12))
sns.countplot(data=top5_agency, y='Agency', hue='Status', ax=tax)
tax.set_title('Appeals by Agency - 2017 (Top 3)')
# Out:
# Text(0.5, 1.0, 'Appeals by Agency - 2017 (Top 3)')
